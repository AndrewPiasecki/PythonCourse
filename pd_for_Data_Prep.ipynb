# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewPiasecki/PythonCourse/blob/main/pd_for_Data_Prep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/DQ-Example-Numeric.csv')
df
# Out:
#     id   age  children_num   salary  taxrate
# 0    1  21.0           2.0  40000.0       22
# 1    2  29.4           0.0  50000.0       25
# 2    3  40.0           1.0     60.0       28
# 3    4   6.0           2.0  45000.0       21
# 4  NaN  -1.0          -1.0  52500.0       25
# 5  six  28.0           1.0  47515.0      100
# 6    4  26.0           NaN      NaN      105

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            6 non-null      object
#  1   age           7 non-null      float64
#  2   children_num  6 non-null      float64
#  3   salary        6 non-null      float64
#  4   taxrate       7 non-null      int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 408.0+ bytes

# %%
df.taxrate.dtype
# Out:
# dtype('int64')

# %%
def lowValues(value):
  if value < 18:
    return None
  else:
    return value

# %%
df['age_clean'] = df['age'].apply(lowValues)
df
# Out:
#     id   age  children_num   salary  taxrate  age_clean
# 0    1  21.0           2.0  40000.0       22       21.0
# 1    2  29.4           0.0  50000.0       25       29.4
# 2    3  40.0           1.0     60.0       28       40.0
# 3    4   6.0           2.0  45000.0       21        NaN
# 4  NaN  -1.0          -1.0  52500.0       25        NaN
# 5  six  28.0           1.0  47515.0      100       28.0
# 6    4  26.0           NaN      NaN      105       26.0

# %%
df['age_clean'] = df['age_clean'].round()
df
# Out:
#     id   age  children_num   salary  taxrate  age_clean
# 0    1  21.0           2.0  40000.0       22       21.0
# 1    2  29.4           0.0  50000.0       25       29.0
# 2    3  40.0           1.0     60.0       28       40.0
# 3    4   6.0           2.0  45000.0       21        NaN
# 4  NaN  -1.0          -1.0  52500.0       25        NaN
# 5  six  28.0           1.0  47515.0      100       28.0
# 6    4  26.0           NaN      NaN      105       26.0

# %%
df[['age', 'age_clean']] #df['age', 'age_clean'] will not work
# Out:
#     age  age_clean
# 0  21.0       21.0
# 1  29.4       29.0
# 2  40.0       40.0
# 3   6.0        NaN
# 4  -1.0        NaN
# 5  28.0       28.0
# 6  26.0       26.0

# %%
df['children_num'] = df['children_num'].astype('float16') # to_numeric() is a thing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            6 non-null      object
#  1   age           7 non-null      float64
#  2   children_num  6 non-null      float16
#  3   salary        6 non-null      float64
#  4   taxrate       7 non-null      int64
#  5   age_clean     5 non-null      float64
# dtypes: float16(1), float64(3), int64(1), object(1)
# memory usage: 422.0+ bytes

# %%
#df[' '] = pd.to_datetime(df[' '], errors = 'coerce')

#df = df.dropna(subset=[' '])

#df[' x.clean '] = df['x'].str.replace(r'[0-9/-]', '', regex = True)

# %%
dfCat = pd.read_csv('/content/sample_data/DQ-Example-Category.csv', index_col = 'id')
dfCat
# Out:
#      age  gender children state
# id
# 1   21.0       m        y    NY
# 2   29.4    male        n    NJ
# 3   40.0       F        Y    IL
# 4    6.0       f        N    CA
# 5   -1.0  female        Y    CT
# 6   28.0  female        N    NY
# 7   26.0     NaN      NaN   NaN

# %%
dfCat.children.unique()
# Out:
# array(['y', 'n', 'Y', 'N', nan], dtype=object)

# %%
dfCat['children_clean'] = dfCat.children.str.lower()
dfCat
# Out:
#      age  gender children state children_clean
# id
# 1   21.0       m        y    NY              y
# 2   29.4    male        n    NJ              n
# 3   40.0       F        Y    IL              y
# 4    6.0       f        N    CA              n
# 5   -1.0  female        Y    CT              y
# 6   28.0  female        N    NY              n
# 7   26.0     NaN      NaN   NaN            NaN

# %%
dfCat['children_clean'] = dfCat.children_clean.map({'y':1, 'n':0})
dfCat
# Out:
#      age  gender children state  children_clean
# id
# 1   21.0       m        y    NY             1.0
# 2   29.4    male        n    NJ             0.0
# 3   40.0       F        Y    IL             1.0
# 4    6.0       f        N    CA             0.0
# 5   -1.0  female        Y    CT             1.0
# 6   28.0  female        N    NY             0.0
# 7   26.0     NaN      NaN   NaN             NaN

# %%
dfCat.astype('category')
# Out:
#      age  gender children state children_clean
# id
# 1   21.0       m        y    NY            1.0
# 2   29.4    male        n    NJ            0.0
# 3   40.0       F        Y    IL            1.0
# 4    6.0       f        N    CA            0.0
# 5   -1.0  female        Y    CT            1.0
# 6   28.0  female        N    NY            0.0
# 7   26.0     NaN      NaN   NaN            NaN
