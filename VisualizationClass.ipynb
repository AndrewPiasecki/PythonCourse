# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewPiasecki/PythonCourse/blob/main/VisualizationClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/cars_pct.csv', index_col = 'Country')
df
# Out:
#                 2020  2019   2018   2017   2016   2015   2014   2013
# Country
# Norway         74.70  55.9  49.10  39.20  29.10  22.40  13.80  6.100
# Iceland        45.00  22.6  19.00  14.05   4.60   2.93   2.71  0.940
# Sweden         32.20  11.4   8.20   5.20   3.50   2.62   1.53  0.710
# Netherlands    24.60  14.9   6.20   2.20   6.70   9.90   3.87  5.550
# Finland        18.10   6.9   4.70   2.57   1.20    NaN    NaN    NaN
# Denmark        16.40   4.2   2.00   0.40   0.60   2.29   0.88  0.290
# Switzerland    14.30   5.5   3.20   2.55   1.80   1.98   0.75  0.440
# Germany        13.50   3.0   1.90   1.58   1.10   0.73   0.43  0.250
# Portugal       13.50   5.7   3.60   1.90    NaN    NaN    NaN    NaN
# France         11.20   2.8   2.11   1.98   1.40   1.19   0.70  0.830
# UK             10.70   2.9   2.53   1.86   1.37   1.07   0.59  0.160
# Belgium        10.70   3.2   2.50   2.70   1.80    NaN    NaN    NaN
# ...

# %%
df.plot()
# Out:
# <Axes: xlabel='Country'>

# %%
df = df.transpose()
df.iloc[:5, :5]
# Out:
# Country  Norway  Iceland  Sweden  Netherlands  Finland
# 2020       74.7    45.00    32.2         24.6    18.10
# 2019       55.9    22.60    11.4         14.9     6.90
# 2018       49.1    19.00     8.2          6.2     4.70
# 2017       39.2    14.05     5.2          2.2     2.57
# 2016       29.1     4.60     3.5          6.7     1.20

# %%
df.index.name = 'Year'
df.iloc[:5, :5]
# Out:
# Country  Norway  Iceland  Sweden  Netherlands  Finland
# Year
# 2020       74.7    45.00    32.2         24.6    18.10
# 2019       55.9    22.60    11.4         14.9     6.90
# 2018       49.1    19.00     8.2          6.2     4.70
# 2017       39.2    14.05     5.2          2.2     2.57
# 2016       29.1     4.60     3.5          6.7     1.20

# %%
df.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
df = df.sort_index()
df.iloc[:5, :5]
# Out:
# Country  Norway  Iceland  Sweden  Netherlands  Finland
# Year
# 2013        6.1     0.94    0.71         5.55      NaN
# 2014       13.8     2.71    1.53         3.87      NaN
# 2015       22.4     2.93    2.62         9.90      NaN
# 2016       29.1     4.60    3.50         6.70     1.20
# 2017       39.2    14.05    5.20         2.20     2.57

# %%
df.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
df[['Iceland', 'Germany', 'Norway']].plot()
# Out:
# <Axes: xlabel='Year'>

# %%
df[['Iceland', 'Germany', 'Norway']].plot(kind = 'bar')
# Out:
# <Axes: xlabel='Year'>

# %%
df[['Iceland', 'Germany', 'Norway']].plot(kind = 'barh')
# Out:
# <Axes: ylabel='Year'>

# %%
df[['Iceland', 'Germany', 'Norway']].sort_values().plot(kind = 'barh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-dbb272358c73> in <cell line: 1>()
# ----> 1 df[['Iceland', 'Germany', 'Norway']].sort_values().plot(kind = 'barh')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'
