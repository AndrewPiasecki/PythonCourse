# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewPiasecki/PythonCourse/blob/main/Exam_2_FirstName_LastName.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Problem 1**

# %% [markdown]
# Assume a program begins with the statement:**
#
# allData = {
# 'US': {'pop':325.7, 'gdp': 19.39, 'ccy': 'USD', 'fx': 1.0},
#
# 'CA': {'pop': 36.5, 'gdp': 1.65, 'ccy': 'CAD', 'fx': 1.35},
#
# 'MX': {'pop':129.2, 'gdp': 1.15, 'ccy': 'MXN', 'fx': 19.68}
#
# }
# Write subsequent statements that (in a loop) prompt the user for a country code (US, CA, or MX), then prompt for a measure name (pop, gdp, ccy, or fx), then look up in the above dictionary for the corresponding value, and display that value.
#
# Example run:
#
# Please enter a country code: CA
#
# Please enter a statistic: pop
#
# CA pop = 36.5
#
# Your program should handle the cases where a user-entered country code or measure name is not found.

# %%
allData = {
    'US': {'pop': 325.7, 'gdp': 19.39, 'ccy': 'USD', 'fx': 1.0},
    'CA': {'pop': 36.5, 'gdp': 1.65, 'ccy': 'CAD', 'fx': 1.35},
    'MX': {'pop': 129.2, 'gdp': 1.15, 'ccy': 'MXN', 'fx': 19.68}
}

while True:
    countryCode = input("Please enter a country code (US, CA, MX): ")

    if countryCode not in allData:
        print("Enter a valid Country Code.")
        continue


    stat = input("Please enter a statistic(pop, gdp, ccy, fx): ")

    if stat not in allData[countryCode]:
        print("Enter a valid Statistic.")
        continue

    result = allData[countryCode][stat]
    print(f"{countryCode} {stat} = {result}")

    again = input("Do you want to check another country and statistic (yes/no)? ")
    if again == 'no':
        break
# Out:
# Please enter a country code (US, CA, MX): ca
# Enter a valid Country Code.
# Please enter a country code (US, CA, MX): CA
# Please enter a statistic(pop, gdp, ccy, fx): ccy
# CA ccy = CAD
# Do you want to check another country and statistic (yes/no)? no

# %% [markdown]
# ## **Problem 2**

# %%
# First, let's create the contacts.csv content
contacts_csv_content = """email,first,last,phone
jsmith@gmail.com,John,Smith,555-1234
mscott@office.com,Michael,Scott,555-4567
djhalpert@office.com,Jim,Halpert,555-7890
pbeesly@office.com,Pam,Beesly,555-1011
smsmith@yahoo.com,Samantha,Smith,555-1213
tessbijon@bijon.com,Tess,Bijon,
danjones@home.com,Dan,Jones,555-1415
"""

# Now, we'll write this content to a CSV file
contacts_csv_file_path = 'contactsE.csv'
with open(contacts_csv_file_path, 'w') as file:
    file.write(contacts_csv_content)

# Next, let's create the contact-states.csv content
contact_states_csv_content = """email,state
jsmith@gmail.com,CA
mscott@office.com,PA
djhalpert@office.com,PA
pbeesly@office.com,PA
smsmith@yahoo.com,NY
tessbijon@bijon.com,TX
danjones@home.com,IL
stefsmith@gmail.com,UT
"""

# And write this content to another CSV file
contact_states_csv_file_path = 'contact-states.csv'
with open(contact_states_csv_file_path, 'w') as file:
    file.write(contact_states_csv_content)

# Returning the paths to the created CSV files
contacts_csv_file_path, contact_states_csv_file_path
# Out:
# ('contactsE.csv', 'contact-states.csv')

# %% [markdown]
# For the following questions, the file contacts.csv is provided, with the following fields: email, first, last, phone. Data in the email field are unique for each row and can be used as the index in a DataFrame.

# %% [markdown]
# ## **Loading and getting information**

# %%
import pandas as pd

# %% [markdown]
# a) Use the pandas read_csv() function to load the data in contacts.csv into a DataFrame. Use the email column as the DataFrame index. Display the data in the DataFrame.

# %%
# a)
df1 = pd.read_csv('/content/sample_data/contactsE.csv', index_col = 'email')
df1
# Out:
#                          first     last     phone
# email
# jsmith@gmail.com          John    Smith  555-1234
# mscott@office.com      Michael    Scott  555-4567
# djhalpert@office.com       Jim  Halpert  555-7890
# pbeesly@office.com         Pam   Beesly  555-1011
# smsmith@yahoo.com     Samantha    Smith  555-1213
# tessbijon@bijon.com       Tess    Bijon       NaN
# danjones@home.com          Dan    Jones  555-1415

# %% [markdown]
# b) Use the info() method to determine how many non-null values there are for each column and what each column’s type is.

# %%
# b)
df1.info()

# They are all objects and there are 7 non-null for first, 7 non-null for last, and 6 non-null for phone
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, jsmith@gmail.com to danjones@home.com
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   7 non-null      object
#  1   last    7 non-null      object
#  2   phone   6 non-null      object
# dtypes: object(3)
# memory usage: 224.0+ bytes

# %% [markdown]
# c) Determine the number of rows and columns using the len() function as well as the shape property.

# %%
# c)
numRows = len(df1)
numColumns = len(df1.columns)

print(numRows, '\n')
print(numColumns, '\n')
print(df1.shape)
# Out:
# 7
#
# 3
#
# (7, 3)

# %% [markdown]
# d) Display the first two and last two rows using head() and tail().

# %%
# d)
print(df1.head(2), '\n')
print(df1.tail(2), '\n')

print(df1) # This is to show that those are the first and last 2 rows
# Out:
#                      first   last     phone
# email
# jsmith@gmail.com      John  Smith  555-1234
# mscott@office.com  Michael  Scott  555-4567
#
#                     first   last     phone
# email
# tessbijon@bijon.com  Tess  Bijon       NaN
# danjones@home.com     Dan  Jones  555-1415
#
#                          first     last     phone
# email
# jsmith@gmail.com          John    Smith  555-1234
# mscott@office.com      Michael    Scott  555-4567
# djhalpert@office.com       Jim  Halpert  555-7890
# pbeesly@office.com         Pam   Beesly  555-1011
# smsmith@yahoo.com     Samantha    Smith  555-1213
# tessbijon@bijon.com       Tess    Bijon       NaN
# danjones@home.com          Dan    Jones  555-1415

# %% [markdown]
# ## **Accessing rows, columns, and cells**

# %% [markdown]
# e) Display the phone column.

# %%
# e)
print(df1[['phone']])
# Out:
#                          phone
# email
# jsmith@gmail.com      555-1234
# mscott@office.com     555-4567
# djhalpert@office.com  555-7890
# pbeesly@office.com    555-1011
# smsmith@yahoo.com     555-1213
# tessbijon@bijon.com        NaN
# danjones@home.com     555-1415

# %% [markdown]
# f) Display the columns named first and last in a DataFrame.

# %%
# f)
print(df1[['first', 'last']])
# Out:
#                          first     last
# email
# jsmith@gmail.com          John    Smith
# mscott@office.com      Michael    Scott
# djhalpert@office.com       Jim  Halpert
# pbeesly@office.com         Pam   Beesly
# smsmith@yahoo.com     Samantha    Smith
# tessbijon@bijon.com       Tess    Bijon
# danjones@home.com          Dan    Jones

# %% [markdown]
# g) Display the phone number for the row with email=smsmith@yahoo.com.

# %%
# g)
df1.loc['smsmith@yahoo.com', 'phone']
# Out:
# '555-1213'

# %% [markdown]
# ## Filtering, sorting

# %% [markdown]
# h) Display the data sorted by last name then first name.

# %%
# h)
df1.sort_values(by=['last', 'first'], inplace=True)
df1
# Out:
#                          first     last     phone
# email
# pbeesly@office.com         Pam   Beesly  555-1011
# tessbijon@bijon.com       Tess    Bijon       NaN
# djhalpert@office.com       Jim  Halpert  555-7890
# danjones@home.com          Dan    Jones  555-1415
# mscott@office.com      Michael    Scott  555-4567
# jsmith@gmail.com          John    Smith  555-1234
# smsmith@yahoo.com     Samantha    Smith  555-1213

# %% [markdown]
# i) Display rows where the first name is Dan.

# %%
# i)
df1[df1['first'] == 'Dan']
# Out:
#                   first   last     phone
# email
# danjones@home.com   Dan  Jones  555-1415

# %% [markdown]
# ## Missing values

# %% [markdown]
# j) Display rows where the phone number is missing.

# %%
# j)
df1[df1['phone'].isna()]
# Out:
#                     first   last phone
# email
# tessbijon@bijon.com  Tess  Bijon   NaN

# %% [markdown]
# ## **Updating**

# %% [markdown]
# k) For the row where email=tessbijon@bijon.com, set the value of phone to '555-1233'.

# %%
# k)
df1.loc['tessbijon@bijon.com', 'phone'] = '555-1233'
df1
# Out:
#                          first     last     phone
# email
# pbeesly@office.com         Pam   Beesly  555-1011
# tessbijon@bijon.com       Tess    Bijon  555-1233
# djhalpert@office.com       Jim  Halpert  555-7890
# danjones@home.com          Dan    Jones  555-1415
# mscott@office.com      Michael    Scott  555-4567
# jsmith@gmail.com          John    Smith  555-1234
# smsmith@yahoo.com     Samantha    Smith  555-1213

# %% [markdown]
# l) Drop the row where email=tessbijon@gmail.com.

# %%
# l)
df1 = df1.drop('tessbijon@bijon.com')
df1
# Out:
#                          first     last     phone
# email
# pbeesly@office.com         Pam   Beesly  555-1011
# djhalpert@office.com       Jim  Halpert  555-7890
# danjones@home.com          Dan    Jones  555-1415
# mscott@office.com      Michael    Scott  555-4567
# jsmith@gmail.com          John    Smith  555-1234
# smsmith@yahoo.com     Samantha    Smith  555-1213

# %% [markdown]
# m) Append a row with the following data:
# email=stefsmith@gmail.com
# First: Stef
# Last: Smith
# Phone: 801-555-9876

# %%
# m)
new_row = {'email': 'stefsmith@gmail.com', 'first': 'Stef', 'last': 'Smith', 'phone': '801-555-9876'}
df1 = df1.append(new_row, ignore_index=True)
df1

# I ran it 3 times on accident
# Out:
# <ipython-input-92-0c9425a88485>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(new_row, ignore_index=True)
#       first     last         phone                email
# 0       Pam   Beesly      555-1011                  NaN
# 1       Jim  Halpert      555-7890                  NaN
# 2       Dan    Jones      555-1415                  NaN
# 3   Michael    Scott      555-4567                  NaN
# 4      John    Smith      555-1234                  NaN
# 5  Samantha    Smith      555-1213                  NaN
# 6      Stef    Smith  801-555-9876  stefsmith@gmail.com
# 7      Stef    Smith  801-555-9876  stefsmith@gmail.com
# 8      Stef    Smith  801-555-9876  stefsmith@gmail.com

# %% [markdown]
# ## **Joining**

# %% [markdown]
# n) The file contact-states.csv has additional data, including email and state. Use join() to augment the DataFrame with the state data.

# %%
#n)




statesDF = pd.read_csv('/content/contact-states.csv')

statesDF.rename(columns={'email': 'state_email'}, inplace=True)
df_combined = df1.join(statesDF)

# %%
df_combined
# Out:
#       first     last         phone                email           state_email  \
# 0       Pam   Beesly      555-1011                  NaN      jsmith@gmail.com
# 1       Jim  Halpert      555-7890                  NaN     mscott@office.com
# 2       Dan    Jones      555-1415                  NaN  djhalpert@office.com
# 3   Michael    Scott      555-4567                  NaN    pbeesly@office.com
# 4      John    Smith      555-1234                  NaN     smsmith@yahoo.com
# 5  Samantha    Smith      555-1213                  NaN   tessbijon@bijon.com
# 6      Stef    Smith  801-555-9876  stefsmith@gmail.com     danjones@home.com
# 7      Stef    Smith  801-555-9876  stefsmith@gmail.com   stefsmith@gmail.com
# 8      Stef    Smith  801-555-9876  stefsmith@gmail.com                   NaN
#
#   state
# 0    CA
# 1    PA
# 2    PA
# 3    PA
# 4    NY
# 5    TX
# 6    IL
# 7    UT
# 8   NaN
